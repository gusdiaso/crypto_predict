# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Bitcoin

# %%
data = pd.read_csv('../../data/processed/BTC-USD_raw.csv', index_col='Date', parse_dates=True)

# %%
data.describe().transpose()
# Out:
#          count          mean           std           min           25%  \
# Close   4058.0  2.575739e+04  3.070204e+04  1.781030e+02  2.555352e+03
# High    4058.0  2.625441e+04  3.120557e+04  2.117310e+02  2.624885e+03
# Low     4058.0  2.518243e+04  3.012093e+04  1.715100e+02  2.484555e+03
# Open    4058.0  2.573090e+04  3.067534e+04  1.768970e+02  2.550030e+03
# Volume  4058.0  2.101521e+10  2.233363e+10  5.914570e+06  1.161268e+09
#
#                  50%           75%           max
# Close   1.040029e+04  4.041993e+04  1.247525e+05
# High    1.067221e+04  4.145368e+04  1.261981e+05
# Low     1.018610e+04  3.936784e+04  1.231960e+05
# Open    1.039797e+04  4.037689e+04  1.247521e+05
# Volume  1.673350e+10  3.249764e+10  3.509679e+11

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(data.corr(), annot=True, cmap="YlGn", fmt=".2f")
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)
data_scaled = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_scaled.index, data_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_scaled.index, data_scaled['Close'], label='Close', color='green')
plt.plot(data_scaled.index, data_scaled['Open'], label='Open', color='blue')
plt.plot(data_scaled.index, data_scaled['High'], label='High', color='orange')
plt.plot(data_scaled.index, data_scaled['Low'], label='Low', color='red')

plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores (Normalizados)')
plt.legend()
plt.show()

# %%
data_all = pd.read_csv('../../data/processed/BTC-USD_all.csv', index_col='Date', parse_dates=True)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data_all = scaler.fit_transform(data_all)
data_all_scaled = pd.DataFrame(scaled_data_all, columns=data_all.columns, index=data_all.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_all_scaled.index, data_all_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_all_scaled.index, data_all_scaled['Close'], label='Close', color='green')
plt.plot(data_all_scaled.index, data_all_scaled['Open'], label='Open', color='blue')
plt.plot(data_all_scaled.index, data_all_scaled['High'], label='High', color='orange')
plt.plot(data_all_scaled.index, data_all_scaled['Low'], label='Low', color='red')

plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores (Normalizados)')
plt.legend()
plt.show()

# %%
data_cropped = pd.read_csv('../../data/processed/BTC-USD_cropped.csv', index_col='Date', parse_dates=True)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data_cropped = scaler.fit_transform(data_cropped)
data_cropped_scaled = pd.DataFrame(scaled_data_cropped, columns=data_cropped.columns, index=data_cropped.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_cropped_scaled.index, data_cropped_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_cropped_scaled.index, data_cropped_scaled['Close'], label='Close', color='green')
plt.plot(data_cropped_scaled.index, data_cropped_scaled['Open'], label='Open', color='blue')
plt.plot(data_cropped_scaled.index, data_cropped_scaled['High'], label='High', color='orange')
plt.plot(data_cropped_scaled.index, data_cropped_scaled['Low'], label='Low', color='red')

plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores (Normalizados)')
plt.legend()
plt.show()

# %% [markdown]
# #### Adicionando Google Trends

# %%
from pytrends.request import TrendReq
import pandas as pd
import time

# Configuração PyTrends
pytrends = TrendReq(hl='en-US', tz=360)

# Termos que você quer pesquisar
kw_list = ["crypto", "bitcoin"]

# Função para gerar intervalos anuais entre datas inicial e final
def generate_halfyear_intervals(start_year, start_month, start_day, end_year, end_month, end_day):
    intervals = []
    current_start = pd.Timestamp(year=start_year, month=start_month, day=start_day)
    final_end = pd.Timestamp(year=end_year, month=end_month, day=end_day)

    while current_start < final_end:
        current_end = current_start + pd.DateOffset(months=6) - pd.DateOffset(days=1)
        if current_end > final_end:
            current_end = final_end
        intervals.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))
        current_start = current_end + pd.DateOffset(days=1)
    return intervals

intervals = generate_halfyear_intervals(2014, 9, 17, 2025, 10, 27)

dfs = []

# Loop para buscar os dados de cada intervalo
for start, end in intervals:
    print(f"Buscando dados de {start} até {end}...")
    pytrends.build_payload(kw_list, cat=0, timeframe=f'{start} {end}', geo='')
    
    # Tentar pegar os dados e lidar com possíveis falhas
    try:
        df = pytrends.interest_over_time()
        if not df.empty:
            dfs.append(df)
    except Exception as e:
        print(f"Erro ao buscar dados: {e}")
    
    # Espera para não ser bloqueado
    time.sleep(60)  

# Concatenar todos os intervalos em um único DataFrame
interest_over_time_df = pd.concat(dfs)
interest_over_time_df = interest_over_time_df[~interest_over_time_df.index.duplicated(keep='first')]
# Out:
# Buscando dados de 2014-09-17 até 2015-03-16...
# Buscando dados de 2015-03-17 até 2015-09-16...
# Buscando dados de 2015-09-17 até 2016-03-16...
# Buscando dados de 2016-03-17 até 2016-09-16...
# Buscando dados de 2016-09-17 até 2017-03-16...
# Buscando dados de 2017-03-17 até 2017-09-16...
# Buscando dados de 2017-09-17 até 2018-03-16...
# Buscando dados de 2018-03-17 até 2018-09-16...
# Buscando dados de 2018-09-17 até 2019-03-16...
# Buscando dados de 2019-03-17 até 2019-09-16...
# Buscando dados de 2019-09-17 até 2020-03-16...
# Buscando dados de 2020-03-17 até 2020-09-16...
# Buscando dados de 2020-09-17 até 2021-03-16...
# Buscando dados de 2021-03-17 até 2021-09-16...
# Buscando dados de 2021-09-17 até 2022-03-16...
# Buscando dados de 2022-03-17 até 2022-09-16...
# Buscando dados de 2022-09-17 até 2023-03-16...
# Buscando dados de 2023-03-17 até 2023-09-16...
# Buscando dados de 2023-09-17 até 2024-03-16...
# Buscando dados de 2024-03-17 até 2024-09-16...
# Buscando dados de 2024-09-17 até 2025-03-16...
# Buscando dados de 2025-03-17 até 2025-09-16...
# Buscando dados de 2025-09-17 até 2025-10-27...

# %%
# Mostrar os primeiros dados
interest_over_time_df.head(10)
# Out:
#             crypto  bitcoin  isPartial
# date
# 2014-09-17       6       48      False
# 2014-09-18       7       51      False
# 2014-09-19       5       56      False
# 2014-09-20       4       49      False
# 2014-09-21       4       50      False
# 2014-09-22       6       52      False
# 2014-09-23       6       58      False
# 2014-09-24       7       59      False
# 2014-09-25       6       52      False
# 2014-09-26       5       49      False

# %%
# Seleciona apenas as colunas de interesse do Google Trends
trends_cols = interest_over_time_df[["crypto", "bitcoin"]]

# Faz o merge pelo índice de datas
data_merged = data.merge(trends_cols, left_index=True, right_index=True, how='left')

# %%
data_merged.head(10)
# Out:
#                  Close        High         Low        Open    Volume  crypto  \
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014  21056800       6
# 2014-09-18  424.440002  456.859985  413.104004  456.859985  34483200       7
# 2014-09-19  394.795990  427.834991  384.532013  424.102997  37919700       5
# 2014-09-20  408.903992  423.295990  389.882996  394.673004  36863600       4
# 2014-09-21  398.821014  412.425995  393.181000  408.084991  26580100       4
# 2014-09-22  402.152008  406.915985  397.130005  399.100006  24127600       6
# 2014-09-23  435.790985  441.557007  396.196991  402.092010  45099500       6
# 2014-09-24  423.204987  436.112000  421.131989  435.751007  30627700       7
# 2014-09-25  411.574005  423.519989  409.467987  423.156006  26814400       6
# 2014-09-26  404.424988  414.937988  400.009003  411.428986  21460800       5
#
#             bitcoin
# Date
# 2014-09-17       48
# 2014-09-18       51
# 2014-09-19       56
# 2014-09-20       49
# 2014-09-21       50
# 2014-09-22       52
# 2014-09-23       58
# 2014-09-24       59
# 2014-09-25       52
# 2014-09-26       49

# %%
data_merged.isna().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# crypto    0
# dtype: int64

# %%
data_merged.drop(columns="bitcoin")
# Out:
#                     Close           High            Low           Open  \
# Date
# 2014-09-17     457.334015     468.174011     452.421997     465.864014
# 2014-09-18     424.440002     456.859985     413.104004     456.859985
# 2014-09-19     394.795990     427.834991     384.532013     424.102997
# 2014-09-20     408.903992     423.295990     389.882996     394.673004
# 2014-09-21     398.821014     412.425995     393.181000     408.084991
# ...                   ...            ...            ...            ...
# 2025-10-22  107688.585938  109115.132812  106778.000000  108491.531250
# 2025-10-23  110069.726562  111288.593750  107548.429688  107679.437500
# 2025-10-24  111033.921875  111842.531250  109770.148438  110069.351562
# 2025-10-25  111641.726562  111947.703125  110704.406250  111032.617188
# 2025-10-27  115290.968750  115290.968750  114557.664062  114557.664062
#
#                  Volume  crypto
# Date
# 2014-09-17     21056800       6
# 2014-09-18     34483200       7
# 2014-09-19     37919700       5
# 2014-09-20     36863600       4
# 2014-09-21     26580100       4
# ...                 ...     ...
# 2025-10-22  80807013218      15
# 2025-10-23  54944076060      15
# 2025-10-24  48160816980      15
# 2025-10-25  24707667305      14
# 2025-10-27  43894853632      16
#
# [4058 rows x 6 columns]

# %%
# data_merged.to_csv('../data/processed/BTC-USD_crypto_all.csv', index=True)

# %%
data_crypto = pd.read_csv('../../data/processed/BTC-USD_crypto_all.csv', index_col='Date', parse_dates=True)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data_crypto)
data_scaled = pd.DataFrame(scaled_data, columns=data_crypto.columns, index=data_crypto.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_scaled.index, data_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_scaled.index, data_scaled['bitcoin'], label='tudBitcoin', color='pink')
plt.plot(data_scaled.index, data_scaled['crypto'], label='Crypto', color='cyan')
plt.plot(data_scaled.index, data_scaled['Close'], label='Close', color='green')
plt.plot(data_scaled.index, data_scaled['Open'], label='Open', color='blue')
plt.plot(data_scaled.index, data_scaled['High'], label='High', color='orange')
plt.plot(data_scaled.index, data_scaled['Low'], label='Low', color='red')


plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores')
plt.legend()
plt.show()

# %%
data_crypto = pd.read_csv('../../data/processed/BTC-USD_crypto_cropped.csv', index_col='Date', parse_dates=True)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data_crypto)
data_scaled = pd.DataFrame(scaled_data, columns=data_crypto.columns, index=data_crypto.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_scaled.index, data_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_scaled.index, data_scaled['bitcoin'], label='tudBitcoin', color='pink')
plt.plot(data_scaled.index, data_scaled['crypto'], label='Crypto', color='cyan')
plt.plot(data_scaled.index, data_scaled['Close'], label='Close', color='green')
plt.plot(data_scaled.index, data_scaled['Open'], label='Open', color='blue')
plt.plot(data_scaled.index, data_scaled['High'], label='High', color='orange')
plt.plot(data_scaled.index, data_scaled['Low'], label='Low', color='red')


plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(data_merged.corr(), annot=True, cmap="YlGn", fmt=".2f")
plt.show()
