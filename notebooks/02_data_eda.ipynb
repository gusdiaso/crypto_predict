# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Bitcoin

# %%
data = pd.read_csv('../data/processed/BTC-USD_raw.csv', index_col='Date', parse_dates=True)

# %%
data.describe().transpose()
# Out:
#          count          mean           std           min           25%  \
# Close   4058.0  2.575739e+04  3.070204e+04  1.781030e+02  2.555352e+03
# High    4058.0  2.625441e+04  3.120557e+04  2.117310e+02  2.624885e+03
# Low     4058.0  2.518243e+04  3.012093e+04  1.715100e+02  2.484555e+03
# Open    4058.0  2.573090e+04  3.067534e+04  1.768970e+02  2.550030e+03
# Volume  4058.0  2.101521e+10  2.233363e+10  5.914570e+06  1.161268e+09
#
#                  50%           75%           max
# Close   1.040029e+04  4.041993e+04  1.247525e+05
# High    1.067221e+04  4.145368e+04  1.261981e+05
# Low     1.018610e+04  3.936784e+04  1.231960e+05
# Open    1.039797e+04  4.037689e+04  1.247521e+05
# Volume  1.673350e+10  3.249764e+10  3.509679e+11

# %%
plt.figure(figsize=(10, 8)) 
sns.heatmap(data.corr(), annot=True, cmap="YlGn", fmt=".2f")
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)
data_scaled = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# %%
plt.figure(figsize=(20,8))

plt.plot(data_scaled.index, data_scaled['Volume'], label='Volume', color='purple')
plt.plot(data_scaled.index, data_scaled['Close'], label='Close', color='green')
plt.plot(data_scaled.index, data_scaled['Open'], label='Open', color='blue')
plt.plot(data_scaled.index, data_scaled['High'], label='High', color='orange')
plt.plot(data_scaled.index, data_scaled['Low'], label='Low', color='red')

plt.title('Atributos ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Valores')
plt.legend()
plt.show()
