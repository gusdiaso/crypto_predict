# %% [markdown]
# ### Extração dos dados da API do Yahoo Finance

# %%
import yfinance as yf
import time
import pandas as pd

# %%
cryptos = ['BTC-USD', 'ETH-USD', 'SOL-USD']

try:
    for crypto in cryptos:
        data = yf.download(crypto, period='max', interval='1d', auto_adjust=True)
        data.to_csv(f'../data/raw/{crypto}.csv')
        if crypto != cryptos[-1]:
            time.sleep(10)

except Exception as err:
    print(f"Não foi possivel baixar os dados: {err}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Não foi possivel baixar os dados: Cannot save file into a non-existent directory: '..\data\raw'

# %% [markdown]
# ### Carregamento, Ajuste e Exportação dos Dados

# %% [markdown]
# #### Bitcoin

# %%
data = pd.read_csv('../../data/raw/ETH-USD.csv')
data = data.iloc[2:,:]
data.head(5)
# Out:
#         Price               Close                High                 Low  \
# 2  2017-11-09   320.8840026855469   329.4519958496094   307.0559997558594
# 3  2017-11-10  299.25299072265625   324.7179870605469      294.5419921875
# 4  2017-11-11   314.6809997558594   319.4530029296875   298.1919860839844
# 5  2017-11-12   307.9079895019531  319.15301513671875  298.51300048828125
# 6  2017-11-13  316.71600341796875   328.4150085449219   307.0249938964844
#
#                  Open      Volume
# 2   308.6449890136719   893249984
# 3   320.6709899902344   885985984
# 4  298.58599853515625   842300992
# 5  314.69000244140625  1613479936
# 6   307.0249938964844  1041889984

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 2 to 2910
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2909 non-null   object
#  1   Close   2909 non-null   object
#  2   High    2909 non-null   object
#  3   Low     2909 non-null   object
#  4   Open    2909 non-null   object
#  5   Volume  2909 non-null   object
# dtypes: object(6)
# memory usage: 136.5+ KB

# %%
cols = ['Close', 'High', 'Low', 'Open', 'Volume']
data[cols] = data[cols].apply(pd.to_numeric, errors='coerce')
data.dtypes
# Out:
# Price      object
# Close     float64
# High      float64
# Low       float64
# Open      float64
# Volume      int64
# dtype: object

# %% [markdown]
# Apliquei a função pd.to_numeric em cada uma dessas colunas que converte os valores pra número (float ou int)<br>
# Se algum valor não puder ser convertido (por exemplo, "ABC", "?", "-"), o parâmetro errors='coerce' manda ele transformar em NaN (valor nulo)

# %%
data = data.rename(columns={'Price': 'Date'})
data['Date'] = pd.to_datetime(data['Date'])
data.dtypes
# Out:
# Date      datetime64[ns]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
data = data.set_index('Date')
data = data.sort_index()
data.head(5)
# Out:
#                  Close        High         Low        Open      Volume
# Date
# 2017-11-09  320.884003  329.451996  307.056000  308.644989   893249984
# 2017-11-10  299.252991  324.717987  294.541992  320.670990   885985984
# 2017-11-11  314.681000  319.453003  298.191986  298.585999   842300992
# 2017-11-12  307.907990  319.153015  298.513000  314.690002  1613479936
# 2017-11-13  316.716003  328.415009  307.024994  307.024994  1041889984

# %% [markdown]
# Agora já ajustei o nome da coluna, transformei para data, coloquei a data como indice do meu dataset e ordenei por garantia, porque vi que a ordem era importante para uma LSTM

# %%
data.isna().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
data[data.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Close, High, Low, Open, Volume]
# Index: []

# %%
data.shape
# Out:
# (2909, 5)

# %%
data.to_csv('../../data/processed/ETH-USD_raw.csv', index=True)

# %%
limite = data['Volume'].quantile(0.999)
data = data[data['Volume'] <= limite]
data.head(5)
# Out:
#                  Close        High         Low        Open      Volume
# Date
# 2017-11-09  320.884003  329.451996  307.056000  308.644989   893249984
# 2017-11-10  299.252991  324.717987  294.541992  320.670990   885985984
# 2017-11-11  314.681000  319.453003  298.191986  298.585999   842300992
# 2017-11-12  307.907990  319.153015  298.513000  314.690002  1613479936
# 2017-11-13  316.716003  328.415009  307.024994  307.024994  1041889984

# %%
data.shape
# Out:
# (2906, 5)

# %%
data.to_csv('../../data/processed/ETH-USD_all.csv', index=True)

# %%
data_lag = data.copy()

n_steps = 30
for time_step in range(1, n_steps+1):
    data_lag['closeLag_'+str(time_step)] = data_lag['Close'].shift(-time_step)

data_lag = data_lag.dropna()
data_lag.isna().sum()
# Out:
# Close          0
# High           0
# Low            0
# Open           0
# Volume         0
# closeLag_1     0
# closeLag_2     0
# closeLag_3     0
# closeLag_4     0
# closeLag_5     0
# closeLag_6     0
# closeLag_7     0
# closeLag_8     0
# closeLag_9     0
# closeLag_10    0
# closeLag_11    0
# closeLag_12    0
# closeLag_13    0
# closeLag_14    0
# closeLag_15    0
# closeLag_16    0
# closeLag_17    0
# closeLag_18    0
# closeLag_19    0
# closeLag_20    0
# closeLag_21    0
# closeLag_22    0
# closeLag_23    0
# closeLag_24    0
# closeLag_25    0
# closeLag_26    0
# closeLag_27    0
# closeLag_28    0
# closeLag_29    0
# closeLag_30    0
# dtype: int64

# %%
data_lag.head(5)
# Out:
#                  Close        High         Low        Open      Volume  \
# Date
# 2017-11-09  320.884003  329.451996  307.056000  308.644989   893249984
# 2017-11-10  299.252991  324.717987  294.541992  320.670990   885985984
# 2017-11-11  314.681000  319.453003  298.191986  298.585999   842300992
# 2017-11-12  307.907990  319.153015  298.513000  314.690002  1613479936
# 2017-11-13  316.716003  328.415009  307.024994  307.024994  1041889984
#
#             closeLag_1  closeLag_2  closeLag_3  closeLag_4  closeLag_5  ...  \
# Date                                                                    ...
# 2017-11-09  299.252991  314.681000  307.907990  316.716003  337.631012  ...
# 2017-11-10  314.681000  307.907990  316.716003  337.631012  333.356995  ...
# 2017-11-11  307.907990  316.716003  337.631012  333.356995  330.924011  ...
# 2017-11-12  316.716003  337.631012  333.356995  330.924011  332.394012  ...
# 2017-11-13  337.631012  333.356995  330.924011  332.394012  347.612000  ...
#
#             closeLag_21  closeLag_22  closeLag_23  closeLag_24  closeLag_25  \
# Date
# 2017-11-09   447.114014   466.540009   463.449005   465.852997   470.204010
# 2017-11-10   466.540009   463.449005   465.852997   470.204010   463.281006
# 2017-11-11   463.449005   465.852997   470.204010   463.281006   428.588013
# 2017-11-12   465.852997   470.204010   463.281006   428.588013   434.407990
# 2017-11-13   470.204010   463.281006   428.588013   434.407990   456.031006
#
#             closeLag_26  closeLag_27  closeLag_28  closeLag_29  closeLag_30
# Date
# 2017-11-09   463.281006   428.588013   434.407990   456.031006   473.502014
# 2017-11-10   428.588013   434.407990   456.031006   473.502014   441.721008
# 2017-11-11   434.407990   456.031006   473.502014   441.721008   515.135986
# 2017-11-12   456.031006   473.502014   441.721008   515.135986   651.431030
# 2017-11-13   473.502014   441.721008   515.135986   651.431030   702.767029
#
# [5 rows x 35 columns]

# %%
data.head(5)
# Out:
#                  Close        High         Low        Open      Volume
# Date
# 2017-11-09  320.884003  329.451996  307.056000  308.644989   893249984
# 2017-11-10  299.252991  324.717987  294.541992  320.670990   885985984
# 2017-11-11  314.681000  319.453003  298.191986  298.585999   842300992
# 2017-11-12  307.907990  319.153015  298.513000  314.690002  1613479936
# 2017-11-13  316.716003  328.415009  307.024994  307.024994  1041889984

# %%
data_lag.shape
# Out:
# (2876, 35)

# %%
data_lag.to_csv('../../data/processed/ETH-USD_lag_all.csv', index=True)

# %%
data = data.loc['2020-06-01':]
data_lag = data_lag.loc['2020-06-01':]

# %%
data.shape
# Out:
# (1971, 5)

# %%
data_lag.shape
# Out:
# (1941, 35)

# %%
data.to_csv('../../data/processed/ETH-USD_cropped.csv', index=True)
data_lag.to_csv('../../data/processed/ETH-USD_lag_cropped.csv', index=True)

# %%
data_crypto_all = pd.read_csv('../../data/processed/ETH-USD_crypto_all.csv', index_col='Date', parse_dates=True)
data_crypto_cropped = data_crypto_all.loc['2020-06-01':]
data_crypto_cropped.to_csv('../../data/processed/ETH-USD_crypto_cropped.csv', index=True)
